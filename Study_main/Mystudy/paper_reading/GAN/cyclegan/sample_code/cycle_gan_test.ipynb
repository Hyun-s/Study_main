# %%
# !pip install kaggle --upgrade
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/기존드라이브/kaggletoken/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

#!kaggle competitions download -c wikipedia-image-caption
# !nvidia-smi

# %%
# !nvidia-smi
# Out:
# Fri Oct 15 05:06:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !mkdir /content/data

# %%
# !unzip /content/drive/MyDrive/kaggle_data/gan-getting-started.zip -d /content/data

# %%
pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.14.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.8 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.14.0

# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa


AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
GCS_PATH = '/content/data'

MONET_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/monet_tfrec/*.tfrec'))
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/photo_tfrec/*.tfrec'))
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))
# Out:
# Monet TFRecord Files: 5
# Photo TFRecord Files: 20

# %%
IMAGE_SIZE = [256, 256]

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    return image

# %%
def load_dataset(filenames, labeled=True, ordered=False):
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
monet_ds = load_dataset(MONET_FILENAMES, labeled=True).batch(1)
photo_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1)

# %%
example_monet = next(iter(monet_ds))[0]
example_photo = next(iter(photo_ds))[0]

plt.subplot(121)
plt.title('Photo')
plt.imshow(example_photo * 0.5 + 0.5)

plt.subplot(122)
plt.title('Monet')
plt.imshow(example_monet * 0.5 + 0.5)

# %%
OUTPUT_CHANNELS = 3

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %%
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %%
def Generator():
    inputs = layers.Input(shape=[256,256,3])

    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

# %%
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

# %%
monet_generator = Generator() # transforms photos to Monet-esque paintings
photo_generator = Generator() # transforms Monet paintings to be more like photos

monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %%
def discriminator_loss(real, generated):
    real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

    generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

    total_disc_loss = real_loss + generated_loss

    return total_disc_loss * 0.5

# %%
def generator_loss(generated):
    return tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)

# %%
def calc_cycle_loss(real_image, cycled_image, LAMBDA):
    loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

    return LAMBDA * loss1

# %%
def identity_loss(real_image, same_image, LAMBDA):
    loss = tf.reduce_mean(tf.abs(real_image - same_image))
    return LAMBDA * 0.5 * loss

# %%
monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
cycle_gan_model = CycleGan(
    monet_generator, photo_generator, monet_discriminator, photo_discriminator
)

cycle_gan_model.compile(
    m_gen_optimizer = monet_generator_optimizer,
    p_gen_optimizer = photo_generator_optimizer,
    m_disc_optimizer = monet_discriminator_optimizer,
    p_disc_optimizer = photo_discriminator_optimizer,
    gen_loss_fn = generator_loss,
    disc_loss_fn = discriminator_loss,
    cycle_loss_fn = calc_cycle_loss,
    identity_loss_fn = identity_loss
)

# %%
cycle_gan_model.fit(
    tf.data.Dataset.zip((monet_ds, photo_ds)),
    epochs=100
)
# Out:
# Epoch 1/100
# 300/300 [==============================] - 131s 247ms/step - monet_gen_loss: 5.1681 - photo_gen_loss: 5.3231 - monet_disc_loss: 0.6647 - photo_disc_loss: 0.6257
# Epoch 2/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 3.6250 - photo_gen_loss: 3.7711 - monet_disc_loss: 0.6493 - photo_disc_loss: 0.6019
# Epoch 3/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 3.5704 - photo_gen_loss: 3.7054 - monet_disc_loss: 0.6349 - photo_disc_loss: 0.6131
# Epoch 4/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 3.4740 - photo_gen_loss: 3.6470 - monet_disc_loss: 0.6393 - photo_disc_loss: 0.5977
# Epoch 5/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 3.3428 - photo_gen_loss: 3.5248 - monet_disc_loss: 0.6332 - photo_disc_loss: 0.5950
# Epoch 6/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 3.2469 - photo_gen_loss: 3.4103 - monet_disc_loss: 0.6211 - photo_disc_loss: 0.5943
# Epoch 7/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 3.2095 - photo_gen_loss: 3.3322 - monet_disc_loss: 0.6118 - photo_disc_loss: 0.5929
# Epoch 8/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 3.2068 - photo_gen_loss: 3.2937 - monet_disc_loss: 0.6071 - photo_disc_loss: 0.5977
# Epoch 9/100
# 300/300 [==============================] - 74s 248ms/step - monet_gen_loss: 3.1933 - photo_gen_loss: 3.2546 - monet_disc_loss: 0.6064 - photo_disc_loss: 0.6020
# Epoch 10/100
# 300/300 [==============================] - 74s 248ms/step - monet_gen_loss: 3.1683 - photo_gen_loss: 3.2004 - monet_disc_loss: 0.6003 - photo_disc_loss: 0.6056
# Epoch 11/100
# 300/300 [==============================] - 74s 248ms/step - monet_gen_loss: 3.1199 - photo_gen_loss: 3.1492 - monet_disc_loss: 0.6024 - photo_disc_loss: 0.6094
# Epoch 12/100
# 300/300 [==============================] - 74s 248ms/step - monet_gen_loss: 3.0753 - photo_gen_loss: 3.0970 - monet_disc_loss: 0.5996 - photo_disc_loss: 0.6098
# Epoch 13/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 3.0375 - photo_gen_loss: 3.0627 - monet_disc_loss: 0.6027 - photo_disc_loss: 0.6087
# Epoch 14/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 3.0017 - photo_gen_loss: 3.0222 - monet_disc_loss: 0.6012 - photo_disc_loss: 0.6104
# Epoch 15/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.9790 - photo_gen_loss: 2.9952 - monet_disc_loss: 0.6000 - photo_disc_loss: 0.6094
# Epoch 16/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.9526 - photo_gen_loss: 2.9738 - monet_disc_loss: 0.6026 - photo_disc_loss: 0.6090
# Epoch 17/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.9297 - photo_gen_loss: 2.9584 - monet_disc_loss: 0.6022 - photo_disc_loss: 0.6079
# Epoch 18/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8982 - photo_gen_loss: 2.9418 - monet_disc_loss: 0.6100 - photo_disc_loss: 0.6039
# Epoch 19/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.8593 - photo_gen_loss: 2.9308 - monet_disc_loss: 0.6179 - photo_disc_loss: 0.6036
# Epoch 20/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.8179 - photo_gen_loss: 2.8853 - monet_disc_loss: 0.6217 - photo_disc_loss: 0.6049
# Epoch 21/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.7889 - photo_gen_loss: 2.8713 - monet_disc_loss: 0.6220 - photo_disc_loss: 0.6058
# Epoch 22/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.7467 - photo_gen_loss: 2.8395 - monet_disc_loss: 0.6265 - photo_disc_loss: 0.6068
# Epoch 23/100
# 300/300 [==============================] - 74s 248ms/step - monet_gen_loss: 2.7494 - photo_gen_loss: 2.8394 - monet_disc_loss: 0.6263 - photo_disc_loss: 0.6103
# Epoch 24/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7576 - photo_gen_loss: 2.8423 - monet_disc_loss: 0.6225 - photo_disc_loss: 0.6121
# Epoch 25/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.7135 - photo_gen_loss: 2.8352 - monet_disc_loss: 0.6221 - photo_disc_loss: 0.5952
# Epoch 26/100
# 300/300 [==============================] - 73s 245ms/step - monet_gen_loss: 2.6784 - photo_gen_loss: 2.7792 - monet_disc_loss: 0.6287 - photo_disc_loss: 0.6127
# Epoch 27/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6369 - photo_gen_loss: 2.7378 - monet_disc_loss: 0.6282 - photo_disc_loss: 0.6138
# Epoch 28/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7093 - photo_gen_loss: 2.8835 - monet_disc_loss: 0.6154 - photo_disc_loss: 0.5689
# Epoch 29/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7473 - photo_gen_loss: 2.8688 - monet_disc_loss: 0.6196 - photo_disc_loss: 0.6025
# Epoch 30/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.6454 - photo_gen_loss: 2.7682 - monet_disc_loss: 0.6208 - photo_disc_loss: 0.6032
# Epoch 31/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6723 - photo_gen_loss: 2.8469 - monet_disc_loss: 0.6173 - photo_disc_loss: 0.5800
# Epoch 32/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6964 - photo_gen_loss: 2.8575 - monet_disc_loss: 0.6176 - photo_disc_loss: 0.5888
# Epoch 33/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.6412 - photo_gen_loss: 2.7914 - monet_disc_loss: 0.6226 - photo_disc_loss: 0.5986
# Epoch 34/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7041 - photo_gen_loss: 2.9700 - monet_disc_loss: 0.6081 - photo_disc_loss: 0.5421
# Epoch 35/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.6858 - photo_gen_loss: 2.9087 - monet_disc_loss: 0.6139 - photo_disc_loss: 0.5685
# Epoch 36/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.7856 - photo_gen_loss: 2.9724 - monet_disc_loss: 0.5999 - photo_disc_loss: 0.5630
# Epoch 37/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6885 - photo_gen_loss: 2.8863 - monet_disc_loss: 0.6105 - photo_disc_loss: 0.5720
# Epoch 38/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6652 - photo_gen_loss: 2.8742 - monet_disc_loss: 0.6134 - photo_disc_loss: 0.5676
# Epoch 39/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6766 - photo_gen_loss: 2.9665 - monet_disc_loss: 0.6104 - photo_disc_loss: 0.5447
# Epoch 40/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7048 - photo_gen_loss: 2.9732 - monet_disc_loss: 0.6105 - photo_disc_loss: 0.5599
# Epoch 41/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6989 - photo_gen_loss: 2.9812 - monet_disc_loss: 0.6031 - photo_disc_loss: 0.5355
# Epoch 42/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6773 - photo_gen_loss: 2.9165 - monet_disc_loss: 0.6084 - photo_disc_loss: 0.5618
# Epoch 43/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6825 - photo_gen_loss: 2.8832 - monet_disc_loss: 0.6037 - photo_disc_loss: 0.5614
# Epoch 44/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6685 - photo_gen_loss: 2.8796 - monet_disc_loss: 0.5979 - photo_disc_loss: 0.5545
# Epoch 45/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6075 - photo_gen_loss: 2.8133 - monet_disc_loss: 0.6070 - photo_disc_loss: 0.5589
# Epoch 46/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6766 - photo_gen_loss: 2.9346 - monet_disc_loss: 0.5975 - photo_disc_loss: 0.5481
# Epoch 47/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6935 - photo_gen_loss: 2.9426 - monet_disc_loss: 0.5975 - photo_disc_loss: 0.5440
# Epoch 48/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6962 - photo_gen_loss: 2.9030 - monet_disc_loss: 0.5931 - photo_disc_loss: 0.5433
# Epoch 49/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.6847 - photo_gen_loss: 2.9128 - monet_disc_loss: 0.5946 - photo_disc_loss: 0.5491
# Epoch 50/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6920 - photo_gen_loss: 2.9917 - monet_disc_loss: 0.5927 - photo_disc_loss: 0.5162
# Epoch 51/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8044 - photo_gen_loss: 3.1126 - monet_disc_loss: 0.5899 - photo_disc_loss: 0.5176
# Epoch 52/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6707 - photo_gen_loss: 2.9476 - monet_disc_loss: 0.5968 - photo_disc_loss: 0.5371
# Epoch 53/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6845 - photo_gen_loss: 2.9085 - monet_disc_loss: 0.5965 - photo_disc_loss: 0.5434
# Epoch 54/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6699 - photo_gen_loss: 2.8990 - monet_disc_loss: 0.5940 - photo_disc_loss: 0.5389
# Epoch 55/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8627 - photo_gen_loss: 3.2077 - monet_disc_loss: 0.5584 - photo_disc_loss: 0.4455
# Epoch 56/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 3.0618 - photo_gen_loss: 3.4095 - monet_disc_loss: 0.5671 - photo_disc_loss: 0.4751
# Epoch 57/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7851 - photo_gen_loss: 3.1092 - monet_disc_loss: 0.5853 - photo_disc_loss: 0.5137
# Epoch 58/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 3.0040 - photo_gen_loss: 3.2355 - monet_disc_loss: 0.5556 - photo_disc_loss: 0.5006
# Epoch 59/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.7469 - photo_gen_loss: 3.0532 - monet_disc_loss: 0.5963 - photo_disc_loss: 0.5179
# Epoch 60/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.7011 - photo_gen_loss: 3.0103 - monet_disc_loss: 0.5995 - photo_disc_loss: 0.5202
# Epoch 61/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6465 - photo_gen_loss: 2.9332 - monet_disc_loss: 0.6007 - photo_disc_loss: 0.5345
# Epoch 62/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6459 - photo_gen_loss: 2.9160 - monet_disc_loss: 0.5997 - photo_disc_loss: 0.5296
# Epoch 63/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6124 - photo_gen_loss: 2.8643 - monet_disc_loss: 0.6039 - photo_disc_loss: 0.5402
# Epoch 64/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6204 - photo_gen_loss: 2.8657 - monet_disc_loss: 0.6020 - photo_disc_loss: 0.5458
# Epoch 65/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.6174 - photo_gen_loss: 2.8475 - monet_disc_loss: 0.6061 - photo_disc_loss: 0.5470
# Epoch 66/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.6740 - photo_gen_loss: 2.9198 - monet_disc_loss: 0.6021 - photo_disc_loss: 0.5409
# Epoch 67/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8665 - photo_gen_loss: 3.2301 - monet_disc_loss: 0.5849 - photo_disc_loss: 0.4837
# Epoch 68/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7444 - photo_gen_loss: 3.0084 - monet_disc_loss: 0.5895 - photo_disc_loss: 0.5253
# Epoch 69/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8505 - photo_gen_loss: 3.1911 - monet_disc_loss: 0.5863 - photo_disc_loss: 0.5129
# Epoch 70/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8430 - photo_gen_loss: 3.2111 - monet_disc_loss: 0.5778 - photo_disc_loss: 0.4808
# Epoch 71/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8278 - photo_gen_loss: 3.1778 - monet_disc_loss: 0.5831 - photo_disc_loss: 0.4917
# Epoch 72/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7498 - photo_gen_loss: 3.0795 - monet_disc_loss: 0.5897 - photo_disc_loss: 0.5016
# Epoch 73/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7048 - photo_gen_loss: 3.0062 - monet_disc_loss: 0.5924 - photo_disc_loss: 0.5203
# Epoch 74/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7476 - photo_gen_loss: 3.0507 - monet_disc_loss: 0.5880 - photo_disc_loss: 0.5042
# Epoch 75/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6858 - photo_gen_loss: 2.9658 - monet_disc_loss: 0.5951 - photo_disc_loss: 0.5247
# Epoch 76/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6916 - photo_gen_loss: 2.9628 - monet_disc_loss: 0.5955 - photo_disc_loss: 0.5447
# Epoch 77/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.7214 - photo_gen_loss: 3.1024 - monet_disc_loss: 0.5910 - photo_disc_loss: 0.4921
# Epoch 78/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7136 - photo_gen_loss: 3.0574 - monet_disc_loss: 0.5992 - photo_disc_loss: 0.4986
# Epoch 79/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6855 - photo_gen_loss: 2.9564 - monet_disc_loss: 0.5957 - photo_disc_loss: 0.5320
# Epoch 80/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6532 - photo_gen_loss: 2.9093 - monet_disc_loss: 0.5968 - photo_disc_loss: 0.5342
# Epoch 81/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.6644 - photo_gen_loss: 2.9280 - monet_disc_loss: 0.5950 - photo_disc_loss: 0.5314
# Epoch 82/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.8546 - photo_gen_loss: 3.2692 - monet_disc_loss: 0.5674 - photo_disc_loss: 0.4768
# Epoch 83/100
# 300/300 [==============================] - 74s 245ms/step - monet_gen_loss: 2.8856 - photo_gen_loss: 3.2804 - monet_disc_loss: 0.5639 - photo_disc_loss: 0.4737
# Epoch 84/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7798 - photo_gen_loss: 3.0760 - monet_disc_loss: 0.5779 - photo_disc_loss: 0.5092
# Epoch 85/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7456 - photo_gen_loss: 3.0318 - monet_disc_loss: 0.5822 - photo_disc_loss: 0.5194
# Epoch 86/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7097 - photo_gen_loss: 2.9663 - monet_disc_loss: 0.5916 - photo_disc_loss: 0.5405
# Epoch 87/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.8166 - photo_gen_loss: 3.1407 - monet_disc_loss: 0.5846 - photo_disc_loss: 0.5083
# Epoch 88/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8964 - photo_gen_loss: 3.3362 - monet_disc_loss: 0.5780 - photo_disc_loss: 0.4709
# Epoch 89/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.7514 - photo_gen_loss: 3.0079 - monet_disc_loss: 0.5845 - photo_disc_loss: 0.5331
# Epoch 90/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7124 - photo_gen_loss: 2.9420 - monet_disc_loss: 0.5920 - photo_disc_loss: 0.5469
# Epoch 91/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 3.2162 - photo_gen_loss: 3.3461 - monet_disc_loss: 0.5201 - photo_disc_loss: 0.4822
# Epoch 92/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 3.0236 - photo_gen_loss: 3.5820 - monet_disc_loss: 0.5637 - photo_disc_loss: 0.4065
# Epoch 93/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.8889 - photo_gen_loss: 3.3235 - monet_disc_loss: 0.5703 - photo_disc_loss: 0.4567
# Epoch 94/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7961 - photo_gen_loss: 3.1244 - monet_disc_loss: 0.5866 - photo_disc_loss: 0.5109
# Epoch 95/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7481 - photo_gen_loss: 3.0397 - monet_disc_loss: 0.5925 - photo_disc_loss: 0.5239
# Epoch 96/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7551 - photo_gen_loss: 3.0398 - monet_disc_loss: 0.5930 - photo_disc_loss: 0.5152
# Epoch 97/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7491 - photo_gen_loss: 3.0141 - monet_disc_loss: 0.5895 - photo_disc_loss: 0.5420
# Epoch 98/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7498 - photo_gen_loss: 2.9868 - monet_disc_loss: 0.5925 - photo_disc_loss: 0.5389
# Epoch 99/100
# 300/300 [==============================] - 74s 246ms/step - monet_gen_loss: 2.7371 - photo_gen_loss: 2.9692 - monet_disc_loss: 0.5953 - photo_disc_loss: 0.5386
# Epoch 100/100
# 300/300 [==============================] - 74s 247ms/step - monet_gen_loss: 2.9249 - photo_gen_loss: 3.1246 - monet_disc_loss: 0.5683 - photo_disc_loss: 0.5101

# %%
_, ax = plt.subplots(5, 2, figsize=(12, 12))
for i, img in enumerate(photo_ds.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %%
_, ax = plt.subplots(5, 2, figsize=(12, 12))
for i, img in enumerate(monet_ds.take(5)):
    prediction = photo_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %%
img = cv2.imread('/content/drive/MyDrive/201710813한현수.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
tmp = cv2.resize(img,(256,256))
#tmp = cv2.cvtColor(tmp,cv2.COLOR_BGR2RGB)
tmp = tmp/256. - 0.5

# %%
tmp = tmp.reshape((1,256,256,3))

# %%
img = cv2.imread('/content/drive/MyDrive/201710813한현수.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
tmp = cv2.resize(img,(256,256))
#tmp = cv2.cvtColor(tmp,cv2.COLOR_BGR2RGB)
tmp = tmp/256. - 0.5 
tmp = tmp.reshape((1,256,256,3))

plt.subplot(121)
plt.imshow(cv2.resize(img,(256,256)))
plt.title('input')
prediction = monet_generator(tmp, training=False)[0].numpy()
plt.subplot(122)
plt.imshow((prediction+0.5))
plt.title('output')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'output')

# %%
img = cv2.imread('/content/ttss.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
tmp = cv2.resize(img,(256,256))
#tmp = cv2.cvtColor(tmp,cv2.COLOR_BGR2RGB)
tmp = tmp/256. - 0.5 
tmp = tmp.reshape((1,256,256,3))
prediction = photo_generator(tmp, training=False)[0].numpy()
plt.subplot(121)
plt.imshow(cv2.resize(img,(256,256)))
plt.title('input')

plt.subplot(122)
plt.imshow((prediction+0.5))
plt.title('output')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'output')
